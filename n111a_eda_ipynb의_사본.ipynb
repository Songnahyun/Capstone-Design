# %% [markdown]
# <a href="https://colab.research.google.com/github/Songnahyun/Capstone-Design/blob/main/n111a_eda_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 1 / NOTE 1*
#
# ---
#
# # 📝 Assignment

# %% [markdown]
# ## 1.데이터셋 불러오기 연습
#
# 다음 url에서 엑셀 파일을 불러오세요. (pandas excel)
#
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx>
#
#   - 데이터셋 변수의 이름은 `df1`, `df2`로 저장하세요.
#   - row가 아닌 column에 '매출액', '영업이익' 이 가도록 데이터를 transpose 하세요.
#   - 이후 아래 링크를 참조하여 첫번째 row를 column name으로 설정하세요.
#
# <https://stackoverflow.com/questions/31328861/python-pandas-replacing-header-with-top-row>
#
# - 파일은 2개의 시트로 구성되어 있으며 각각 이름은 `008770`, `035250` 입니다.

# %%
import pandas as pd
#008770
url = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx'
df1 = pd.read_excel(url, sheet_name = 0)
#행, 열 바꾸기
df1 = df1.transpose()
#인덱스 버리고 컬럼이름 맨 위로 올리기
df1 = df1.rename(columns = df1.iloc[0]).drop(df1.index[0])
df1.head()
# Out:
#                      매출액 영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)  14753  574        574  ...        0     NaN         0
# 2019/12\n(IFRS연결)  15440  776        776  ...      350     NaN     34.94
# 2020/03\n(IFRS연결)   9437 -668       -668  ...      NaN     NaN         0
# 2020/06\n(IFRS연결)   5230 -634       -634  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)   8795 -198       -198  ...      NaN     NaN       NaN
#
# [5 rows x 32 columns]

# %%
#035250
url = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/stocks/Travel.xlsx'
df2 = pd.read_excel(url, sheet_name = 1)
df2 = df2.T
df2 = df2.rename(columns = df2.iloc[0]).drop(df2.index[0])
df2.head()
# Out:
#                     매출액  영업이익 영업이익(발표기준)  ... 현금DPS(원) 현금배당수익률 현금배당성향(%)
# 2019/09\n(IFRS연결)  4055  1392       1392  ...        0     NaN         0
# 2019/12\n(IFRS연결)  3728   641        641  ...      900     NaN    346.75
# 2020/03\n(IFRS연결)  2360 -1868      -1868  ...      NaN     NaN       NaN
# 2020/06\n(IFRS연결)   346 -1038      -1038  ...      NaN     NaN         0
# 2020/09\n(IFRS연결)   766  -649       -649  ...      NaN     NaN       NaN
#
# [5 rows x 32 columns]

# %% [markdown]
# ## 2. 데이터 확인
#
# - 데이터의 dimension을 확인하세요.
# - 데이터의 결측치가 어디에 있는지 확인 후 0으로 대체하세요.
# - 각 데이터 별로 **FCF**의 값을 barplot으로 시각화하세요.
#   - 0보다 큰 값인 셀 개수의 총합을 `num1`에, 작은 값인 셀 개수의 총합을 `num2`에 저장하세요

# %%
print(df1.shape)
print(df1.size)
print(len(df1))
print(df2.shape)
print(df2.size)
print(len(df2))
# Out:
# (8, 32)
# 256
# 8
# (8, 32)
# 256
# 8

# %%
df1.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    3
# 세전계속사업이익      0
# 당기순이익         0
# 당기순이익(지배)     0
# 당기순이익(비지배)    3
# 자산총계          2
# 부채총계          2
# 자본총계          2
# 자본총계(지배)      2
# 자본총계(비지배)     3
# 자본금           2
# 영업활동현금흐름      3
# 투자활동현금흐름      3
# 재무활동현금흐름      3
# CAPEX         3
# FCF           3
# 이자발생부채        3
# 영업이익률         0
# 순이익률          0
# ROE(%)        3
# ROA(%)        3
# 부채비율          2
# 자본유보율         3
# EPS(원)        0
# PER(배)        5
# BPS(원)        2
# PBR(배)        2
# 현금DPS(원)      6
# 현금배당수익률       8
# 현금배당성향(%)     4
# dtype: int64

# %%
df1 = df1.fillna(0)
df1.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    0
# 세전계속사업이익      0
# 당기순이익         0
# 당기순이익(지배)     0
# 당기순이익(비지배)    0
# 자산총계          0
# 부채총계          0
# 자본총계          0
# 자본총계(지배)      0
# 자본총계(비지배)     0
# 자본금           0
# 영업활동현금흐름      0
# 투자활동현금흐름      0
# 재무활동현금흐름      0
# CAPEX         0
# FCF           0
# 이자발생부채        0
# 영업이익률         0
# 순이익률          0
# ROE(%)        0
# ROA(%)        0
# 부채비율          0
# 자본유보율         0
# EPS(원)        0
# PER(배)        0
# BPS(원)        0
# PBR(배)        0
# 현금DPS(원)      0
# 현금배당수익률       0
# 현금배당성향(%)     0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    3
# 세전계속사업이익      2
# 당기순이익         2
# 당기순이익(지배)     0
# 당기순이익(비지배)    3
# 자산총계          2
# 부채총계          2
# 자본총계          2
# 자본총계(지배)      2
# 자본총계(비지배)     6
# 자본금           2
# 영업활동현금흐름      3
# 투자활동현금흐름      3
# 재무활동현금흐름      3
# CAPEX         3
# FCF           3
# 이자발생부채        3
# 영업이익률         0
# 순이익률          2
# ROE(%)        3
# ROA(%)        3
# 부채비율          2
# 자본유보율         3
# EPS(원)        0
# PER(배)        5
# BPS(원)        2
# PBR(배)        2
# 현금DPS(원)      6
# 현금배당수익률       8
# 현금배당성향(%)     5
# dtype: int64

# %%
df2 = df2.fillna(0)
df2.isnull().sum()
# Out:
# 매출액           0
# 영업이익          0
# 영업이익(발표기준)    0
# 세전계속사업이익      0
# 당기순이익         0
# 당기순이익(지배)     0
# 당기순이익(비지배)    0
# 자산총계          0
# 부채총계          0
# 자본총계          0
# 자본총계(지배)      0
# 자본총계(비지배)     0
# 자본금           0
# 영업활동현금흐름      0
# 투자활동현금흐름      0
# 재무활동현금흐름      0
# CAPEX         0
# FCF           0
# 이자발생부채        0
# 영업이익률         0
# 순이익률          0
# ROE(%)        0
# ROA(%)        0
# 부채비율          0
# 자본유보율         0
# EPS(원)        0
# PER(배)        0
# BPS(원)        0
# PBR(배)        0
# 현금DPS(원)      0
# 현금배당수익률       0
# 현금배당성향(%)     0
# dtype: int64

# %%
# 글꼴 설치
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# 글꼴 설정
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')
plt.rc('axes', unicode_minus=False)

#그래프 화질 설정
from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# fonts-nanum is already the newest version (20170925-1).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.
# /usr/share/fonts: caching, new cache contents: 0 fonts, 1 dirs
# /usr/share/fonts/truetype: caching, new cache contents: 0 fonts, 3 dirs
# /usr/share/fonts/truetype/humor-sans: caching, new cache contents: 1 fonts, 0 dirs
# /usr/share/fonts/truetype/liberation: caching, new cache contents: 16 fonts, 0 dirs
# /usr/share/fonts/truetype/nanum: caching, new cache contents: 10 fonts, 0 dirs
# /usr/local/share/fonts: caching, new cache contents: 0 fonts, 0 dirs
# /root/.local/share/fonts: skipping, no such directory
# /root/.fonts: skipping, no such directory
# /var/cache/fontconfig: cleaning cache directory
# /root/.cache/fontconfig: not cleaning non-existent cache directory
# /root/.fontconfig: not cleaning non-existent cache directory
# fc-cache: succeeded

# %%
#df1[FCF] bar plot
df1['FCF'].plot.bar();

# %%
#df2[FCF] bar plot
df2['FCF'].plot.bar();

# %%
num1 = df1[df1[["FCF"]]>0].count().sum()+df2[df2[["FCF"]]>0].count().sum()
num2 = df1[df1[["FCF"]]<0].count().sum()+df2[df2[["FCF"]]<0].count().sum()
print(num1)
print(num2)
# Out:
# 4
# 6

# %% [markdown]
# ## 3. File export
#
# - 읽었던 엑셀 파일의 내용을 2개의 csv로 각각 출력하세요. (python export csv)
#
#   - 이름은 각각 `df1.csv`, `df2.csv` 입니다.

# %%
# df1, df2 csv로 저장하기
df1.csv = df1.to_csv("./df1.csv", index = True)
df2.csv = df2.to_csv("./df2.csv", index = True)

# %% [markdown]
# ## 4. Error Handling
#
# - 다음의 에러를 고치세요. 결과값은 6912가 나와야합니다.

# %%
#a = '1234'
#b = 5678

#a+b

a = 1234
b = 5678
a+b
# Out:
# 6912

# %% [markdown]
# ## 5. EDA
#
# 아래의 코드는 palmer penguin 데이터를 불러올 수 있는 코드입니다.
#
# ```python
# import seaborn as sns
#
# pp = sns.load_dataset('penguins')
# ```
#
# 이를 참조하여, `pp`의 `species`와 `sex`변수에 대해서 cross-tabulation을 시행하고, 6개의 값들 중 가장 큰 값을 `num3`에, 가장 작은 값을 `num4`에 저장하세요.

# %%
import seaborn as sns

pp = sns.load_dataset('penguins')
pp
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 3    Adelie  Torgersen             NaN  ...                NaN          NaN     NaN
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# ..      ...        ...             ...  ...                ...          ...     ...
# 339  Gentoo     Biscoe             NaN  ...                NaN          NaN     NaN
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# ...

# %%
# species와 sex변수에 대한 cross-tabulation
pp1 = pd.crosstab(pp.species, pp.sex)
pp1
# Out:
# sex        Female  Male
# species
# Adelie         73    73
# Chinstrap      34    34
# Gentoo         58    61

# %%
num3 = pp1.max()[0]
num4 = pp1.min()[0]
print(num3)
print(num4)
# Out:
# 73
# 34

# %% [markdown]
# ## 🔥 도전과제

# %% [markdown]
# ### penguins 데이터를 계속 사용합니다.
#
# 이에 대해 아래의 task들을 시행하세요.
#
# - 결측치 처리 (제거)
#
# - bill_length_mm에 대해서 qqplot 그리기
#
# - island에 대해서 다른 4개의 numerical feature 를 boxplot으로 표현하기
#
# - 각 numerical feature에 대해서 summary statistics : mean, sd, Quantiles(1Q, 2Q, 3Q, 4Q)를 계산하세요.

# %%
# 결측치 제거
pp = pp.dropna()
pp
# Out:
#     species     island  bill_length_mm  ...  flipper_length_mm  body_mass_g     sex
# 0    Adelie  Torgersen            39.1  ...              181.0       3750.0    Male
# 1    Adelie  Torgersen            39.5  ...              186.0       3800.0  Female
# 2    Adelie  Torgersen            40.3  ...              195.0       3250.0  Female
# 4    Adelie  Torgersen            36.7  ...              193.0       3450.0  Female
# 5    Adelie  Torgersen            39.3  ...              190.0       3650.0    Male
# ..      ...        ...             ...  ...                ...          ...     ...
# 338  Gentoo     Biscoe            47.2  ...              214.0       4925.0  Female
# 340  Gentoo     Biscoe            46.8  ...              215.0       4850.0  Female
# 341  Gentoo     Biscoe            50.4  ...              222.0       5750.0    Male
# 342  Gentoo     Biscoe            45.2  ...              212.0       5200.0  Female
# ...

# %%
#bill_length_mm에 대해서 qqplot 그리기
from statsmodels.graphics.gofplots import qqplot 
from matplotlib import pyplot as plt

qqplot(pp["bill_length_mm"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
import seaborn as sns

f, ax = plt.subplots(2, 2, figsize = (15, 15))

x = 'person_attribute_a'
y = 'target'

sns.boxplot(x = "species", y = "bill_length_mm",palette = 'Set2', data = pp, ax = ax[0][0])
sns.boxplot(x = "species", y = "bill_depth_mm", palette = 'Set2', data = pp, ax = ax[0][1])
sns.boxplot(x = "species", y = "flipper_length_mm", palette = 'Set2', data = pp, ax = ax[1][0])
sns.boxplot(x = "species", y = "body_mass_g", palette = 'Set2', data = pp, ax = ax[1][1])

plt.show()

# %%
pp.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm  body_mass_g
# count      333.000000     333.000000         333.000000   333.000000
# mean        43.992793      17.164865         200.966967  4207.057057
# std          5.468668       1.969235          14.015765   805.215802
# min         32.100000      13.100000         172.000000  2700.000000
# 25%         39.500000      15.600000         190.000000  3550.000000
# 50%         44.500000      17.300000         197.000000  4050.000000
# 75%         48.600000      18.700000         213.000000  4775.000000
# max         59.600000      21.500000         231.000000  6300.000000
